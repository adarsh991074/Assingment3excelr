# %%
import numpy as np
import scipy.stats as st
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as sm
from scipy.stats import chi2_contingency

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Documents'

# %%
#null hypothesis
#pmean=peman2

# %% [markdown]
# # q1

# %%
os.listdir('C:/Users/hp/downloads')
# Out:
# ['.ipynb_checkpoints',
#  '2032052303512.pdf',
#  '2032052303512~1.pdf',
#  '2032052303512~2.pdf',
#  'AADHAR UPDATION APP.FORM.pdf',
#  'acknowledgement-1686798024919.pdf',
#  'Adarsh CV--1.pdf',
#  'Anaconda3-2023.03-1-Windows-x86_64.exe',
#  'Assignment (1).docx',
#  'Assignment 2.ipynb',
#  'Assignment.docx',
#  'Basic_statsitics_level 1 (1).docx',
#  'Basic_statsitics_level 1.docx',
#  'BingWallpaper.exe',
#  'Book3.xlsx',
#  'BuyerRatio.csv',
#  'Cars.csv',
#  'certificate.jpg',
#  'ChromeStandaloneSetup64.exe',
#  'Costomer+OrderForm.csv',
#  'Cutlets.csv',
#  'CV AVISHEK 1.pdf',
#  'CV JYOTI -1.pdf',
#  'CV JYOTI.pdf',
#  'Data Science Assignment (1).ipynb',
#  'desktop.ini',
#  'f9e88e2f575a3cf66efc8dbf1e6cf715.doc',
#  'Global+Superstore.xlsb',
#  'HP_M1130_M1210_MFP_Full_Solution-v20180815-10158769_1.exe',
#  'Hypothesis_Testing_Assignment.pptx',
#  'IMG20230629180443.jpg',
#  'IMG_20230615_082315.jpg',
#  'krishna.png',
#  'LabTAT.csv',
# ...

# %%
data=pd.read_csv('C:/Users/hp/downloads/Cutlets.csv')

# %%
data
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
unitA=pd.Series(data.iloc[:,0])

# %%
unitB=pd.Series(data.iloc[:,1])

# %%
p_value=st.ttest_ind(unitA,unitB)

# %%
p_value
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %%
#a=0.05

# %%
alpha=0.05

# %%
#as this is two tail test 
alpha=0.05/2

# %%
alpha
# Out:
# 0.025

# %%
#as alpha is is not equal to p then we failed to reject null hypothesis

# %%
plt.subplots(figsize=(10,9))

plt.boxplot(data['Unit A'])
plt.title('Unit A')
# Out:
# Text(0.5, 1.0, 'Unit A')

# %%
plt.boxplot(data['Unit B'])
plt.title('Unit B')
# Out:
# Text(0.5, 1.0, 'Unit B')

# %%
plt.hist(data['Unit A'],bins=20)
# Out:
# (array([1., 1., 2., 0., 2., 0., 2., 3., 2., 5., 1., 1., 1., 2., 1., 4., 2.,
#         3., 1., 1.]),
#  array([6.4376  , 6.491565, 6.54553 , 6.599495, 6.65346 , 6.707425,
#         6.76139 , 6.815355, 6.86932 , 6.923285, 6.97725 , 7.031215,
#         7.08518 , 7.139145, 7.19311 , 7.247075, 7.30104 , 7.355005,
#         7.40897 , 7.462935, 7.5169  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(data['Unit B'])
# Out:
# (array([1., 1., 0., 2., 9., 5., 3., 7., 2., 5.]),
#  array([6.038  , 6.18879, 6.33958, 6.49037, 6.64116, 6.79195, 6.94274,
#         7.09353, 7.24432, 7.39511, 7.5459 ]),
#  <BarContainer object of 10 artists>)

# %%
lables=['Unit A','Unit B']

sn.distplot(data['Unit A'])
sn.distplot(data['Unit B'])
plt.legend(lables)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\2508139766.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Unit A'])
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\2508139766.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Unit B'])

# %%
sm.qqplot(data['Unit A'],line='q')
plt.title('Unit A')
sm.qqplot(data['Unit B'],line='q')
plt.title('Unit B')
# Out:
# Text(0.5, 1.0, 'Unit B')

# %%
os.listdir('C:/Users/hp/downloads')
# Out:
# ['.ipynb_checkpoints',
#  '2032052303512.pdf',
#  '2032052303512~1.pdf',
#  '2032052303512~2.pdf',
#  'AADHAR UPDATION APP.FORM.pdf',
#  'acknowledgement-1686798024919.pdf',
#  'Adarsh CV--1.pdf',
#  'Anaconda3-2023.03-1-Windows-x86_64.exe',
#  'Assignment (1).docx',
#  'Assignment 2.ipynb',
#  'Assignment.docx',
#  'Basic_statsitics_level 1 (1).docx',
#  'Basic_statsitics_level 1.docx',
#  'BingWallpaper.exe',
#  'Book3.xlsx',
#  'BuyerRatio.csv',
#  'Cars.csv',
#  'certificate.jpg',
#  'ChromeStandaloneSetup64.exe',
#  'Costomer+OrderForm.csv',
#  'Cutlets.csv',
#  'CV AVISHEK 1.pdf',
#  'CV JYOTI -1.pdf',
#  'CV JYOTI.pdf',
#  'Data Science Assignment (1).ipynb',
#  'desktop.ini',
#  'f9e88e2f575a3cf66efc8dbf1e6cf715.doc',
#  'Global+Superstore.xlsb',
#  'HP_M1130_M1210_MFP_Full_Solution-v20180815-10158769_1.exe',
#  'Hypothesis_Testing_Assignment.pptx',
#  'IMG20230629180443.jpg',
#  'IMG_20230615_082315.jpg',
#  'krishna.png',
#  'LabTAT.csv',
# ...

# %%
#q2

# %%
labdata=pd.read_csv('C:/Users/hp/downloads/LabTAT.csv')

# %%
labdata
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
'''null hypothesis--
pmean1=pmean2
alternate hypothesis 
pmean1 not equal to pmean2'''
# Out:
# 'null hypothesis--\npmean1=pmean2\nalternate hypothesis \npmean1 not equal to pmean2'

# %%
p_value=st.f_oneway(labdata.iloc[:,0],labdata.iloc[:,1],labdata.iloc[:,2],labdata.iloc[:,3])
#p_value=stats.f_oneway(data.iloc[:,0],data.iloc[:,1],data.iloc[:,2],data.iloc[:,3])

# %%
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
#hence p_value is not equal to  0.05 , hence we  fail to reject null hypothesis

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 plt.boxplot(labdata('Laboratory 1'))
#
# TypeError: 'DataFrame' object is not callable

# %%
plt.subplots(figsize=(9,6))
plt.subplot(2,2,1)
plt.hist(labdata['Laboratory 1'])
plt.title('Laboratory 1')

plt.subplot(2,3,2)
plt.hist(labdata['Laboratory 2'])
plt.title('Laboratory 2')

plt.subplot(3,2,3)
plt.hist(labdata['Laboratory 3'])
plt.title('Laboratory 3')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\2984665502.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1)
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\2984665502.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,3,2)
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\2984665502.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,3)

# %%
sn.distplot(labdata['Laboratory 1'])
sn.distplot(labdata['Laboratory 2'])
sn.distplot(labdata['Laboratory 3'])
sn.distplot(labdata['Laboratory 4'])
labels='Lab1','Lab2','Lab3','Lab4'
plt.legend(labels)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\3729488762.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(labdata['Laboratory 1'])
# C:\Users\hp\AppData\Local\Temp\ipykernel_31144\3729488762.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sm.qqplot(labdata['Laboratory 1' ],line='q')

# %%
#q4

# %%
obs=pd.read_csv('C:/Users/hp/downloads/Costomer+OrderForm.csv')

# %%
obs
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
obs.value_counts('Phillippines')
# Out:
# Phillippines
# Error Free    271
# Defective      29
# dtype: int64

# %%
obs.value_counts('Indonesia')
# Out:
# Indonesia
# Error Free    267
# Defective      33
# dtype: int64

# %%
obs.value_counts('Malta')
# Out:
# Malta
# Error Free    269
# Defective      31
# dtype: int64

# %%
obs.value_counts('India')
# Out:
# India
# Error Free    280
# Defective      20
# dtype: int64

# %%
#make contiguency table

# %%
data=np.array([[271,267,269,280],[29,33,31,20]])

# %%
chi2_contingency(data)
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
#we fail to  reject

# %%
#q3

# %%
data=pd.read_csv('C:/Users/hp/downloads/BuyerRatio.csv')

# %%
data.value_counts()
# Out:
# Observed Values  East  West  North  South
# Females          435   1523  1356   750      1
# Males            50    142   131    70       1
# dtype: int64

# %%
obs=np.array([[435,1523,1356,750],[50,142,131,70]])

# %%
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948],
#        [  42.76531299,  146.81287862,  131.11756787,   72.30424052]]))

# %%
#p value greater than 0.05 hence we fail to reject
